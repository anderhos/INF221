# %%
import pandas as pd
import numpy as np
import timeit
import copy

# %%
# Code from L03

def merge(A, p, q, r):    
    n1 = q - p + 1
    n2 = r - q
    
    L = [0] * n1
    R = [0] * n2

    for i in list(range(n1)):
        L[i] = A[p + i - 1]
    
    for j in list(range(n2)):
        R[j] = A[q + j]
    L.append(float('inf'))
    R.append(float('inf'))

    i = 1 - 1     # Subtract 1 to adjust to Python indexing
    j = 1 - 1     # Subtract 1 to adjust to Python indexing
    
    for k in list(range(p - 1, r)):     # Subtract 1 from q to adjust to Python range object
        if L[i] <= R[j]:
            A[k] = L[i]
            i = i + 1
        else:
            A[k] = R[j]
            j = j + 1
    return A

# %%
# See p 34 book for algo
def _merge_sort(A, p, r):
    if p < r:
        q = (p + r) // 2
        _merge_sort(A, p, q)
        _merge_sort(A, q + 1, r)
        merge(A, p, q, r)
    return A

# %%
def merge_sort(A):
    """
    Ad hoc code.
    Algorithm must take only one input to work with benchmarking
    below.
    """
    p = 1
    r = len(A)
    _merge_sort(A, p, r)
    return A

# %%
a = [99, 33, -11, 45]

merge_sort(a)
# Out:
# [-11, 33, 45, 99]

# %% [markdown]
# ### Benchmarking

# %%
benchmark_results_mergesort = pd.DataFrame(columns = 
                                          ['input ordering', 'input size',
                                           'run number','sorting algorithm',
                                           'time'])

# %%
# Source TP 2019

for input_ordering in ['sorted','reversed','random','identical']:
    
    for input_size in range(1,4):
        rng = np.random.default_rng(12)
        test_data = np.random.uniform(size=10**input_size)
        
        if input_ordering == 'sorted':
            test_data = sorted(test_data)
        
        elif input_ordering == 'reversed':
            test_data = list(reversed(sorted(test_data)))
        
        elif input_ordering == 'identical':
            test_data = [test_data]*0
            
        clock = timeit.Timer(stmt='sort_func(copy(data))',
                     globals={'sort_func': merge_sort,
                              'data': test_data,
                              'copy': copy.copy})
        n_ar, t_ar = clock.autorange()
        t = clock.repeat(repeat=5, number=n_ar)  
        
        print(f"mergesort minimum time on {input_ordering} \
              data of size 10^{input_size}:", min(t)/n_ar)
        
        
        for run_number in range(5):
            benchmark_results_mergesort = \
                                benchmark_results_mergesort.append(
                                {'input ordering': input_ordering,                        
                                 'input size':10**input_size,
                                  'run number':run_number+1,
                                  'sorting algorithm':'merge_sort',
                                  'time':t[run_number]/n_ar},
                                     ignore_index=True)
# Out:
# mergesort minimum time on sorted               data of size 10^1: 3.9032620000000404e-05
# mergesort minimum time on sorted               data of size 10^2: 0.0005033344999998235
# mergesort minimum time on sorted               data of size 10^3: 0.006388038000000052
# mergesort minimum time on reversed               data of size 10^1: 3.976275999998507e-05
# mergesort minimum time on reversed               data of size 10^2: 0.0005065806000000066
# mergesort minimum time on reversed               data of size 10^3: 0.006403950000003533
# mergesort minimum time on random               data of size 10^1: 4.8432999999999995e-05
# mergesort minimum time on random               data of size 10^2: 0.0006393409999998312
# mergesort minimum time on random               data of size 10^3: 0.008252345000005334
# mergesort minimum time on identical               data of size 10^1: 5.703484999997955e-07
# mergesort minimum time on identical               data of size 10^2: 5.728579999999966e-07
# mergesort minimum time on identical               data of size 10^3: 5.728977999999642e-07

# %%
benchmark_results_mergesort.to_pickle(r"C:\Users\ander\Documents\Data-Science\INF221\term_paper\data\benchmark_results_mergesort.pkl")

# %%
pd.read_pickle(r"C:\Users\ander\Documents\Data-Science\INF221\term_paper\data\benchmark_results_mergesort.pkl")
# Out:
#    input ordering input size run number sorting algorithm          time
# 0          sorted         10          1        merge_sort  4.001796e-05
# 1          sorted         10          2        merge_sort  3.903884e-05
# 2          sorted         10          3        merge_sort  3.903262e-05
# 3          sorted         10          4        merge_sort  3.904634e-05
# 4          sorted         10          5        merge_sort  4.744384e-05
# 5          sorted        100          1        merge_sort  9.570875e-04
# 6          sorted        100          2        merge_sort  5.635730e-04
# 7          sorted        100          3        merge_sort  5.033345e-04
# 8          sorted        100          4        merge_sort  5.271800e-04
# 9          sorted        100          5        merge_sort  5.196790e-04
# 10         sorted       1000          1        merge_sort  6.422334e-03
# 11         sorted       1000          2        merge_sort  6.489040e-03
# 12         sorted       1000          3        merge_sort  6.453126e-03
# 13         sorted       1000          4        merge_sort  6.388038e-03
# 14         sorted       1000          5        merge_sort  6.420930e-03
# 15       reversed         10          1        merge_sort  4.059262e-05
# 16       reversed         10          2        merge_sort  4.064716e-05
# 17       reversed         10          3        merge_sort  4.723030e-05
# 18       reversed         10          4        merge_sort  3.976276e-05
# 19       reversed         10          5        merge_sort  4.186130e-05
# 20       reversed        100          1        merge_sort  6.267968e-04
# 21       reversed        100          2        merge_sort  5.989622e-04
# 22       reversed        100          3        merge_sort  8.117634e-04
# 23       reversed        100          4        merge_sort  5.065806e-04
# 24       reversed        100          5        merge_sort  5.116138e-04
# 25       reversed       1000          1        merge_sort  1.181392e-02
# 26       reversed       1000          2        merge_sort  7.509710e-03
# 27       reversed       1000          3        merge_sort  1.023762e-02
# 28       reversed       1000          4        merge_sort  6.429070e-03
# 29       reversed       1000          5        merge_sort  6.403950e-03
# 30         random         10          1        merge_sort  4.843300e-05
# 31         random         10          2        merge_sort  4.863984e-05
# 32         random         10          3        merge_sort  4.956706e-05
# 33         random         10          4        merge_sort  4.877832e-05
# 34         random         10          5        merge_sort  4.905104e-05
# 35         random        100          1        merge_sort  8.137025e-04
# 36         random        100          2        merge_sort  6.410990e-04
# 37         random        100          3        merge_sort  6.393410e-04
# 38         random        100          4        merge_sort  6.653240e-04
# 39         random        100          5        merge_sort  6.442735e-04
# 40         random       1000          1        merge_sort  8.434575e-03
# 41         random       1000          2        merge_sort  8.256345e-03
# 42         random       1000          3        merge_sort  8.326240e-03
# 43         random       1000          4        merge_sort  8.252345e-03
# 44         random       1000          5        merge_sort  8.305555e-03
# 45      identical         10          1        merge_sort  7.156095e-07
# 46      identical         10          2        merge_sort  5.968750e-07
# 47      identical         10          3        merge_sort  5.757125e-07
# 48      identical         10          4        merge_sort  5.703485e-07
# 49      identical         10          5        merge_sort  5.816750e-07
# 50      identical        100          1        merge_sort  5.993728e-07
# 51      identical        100          2        merge_sort  5.737530e-07
# 52      identical        100          3        merge_sort  5.728580e-07
# 53      identical        100          4        merge_sort  5.833654e-07
# 54      identical        100          5        merge_sort  5.737620e-07
# 55      identical       1000          1        merge_sort  7.858730e-07
# 56      identical       1000          2        merge_sort  5.781402e-07
# 57      identical       1000          3        merge_sort  5.728978e-07
# 58      identical       1000          4        merge_sort  7.399918e-07
# 59      identical       1000          5        merge_sort  7.310674e-07

# %% [markdown]
# ### Combined algorithm

# %%
import pandas as pd
import numpy as np

# %%
# Code from L02

def insertion_sort(A):
    for j in range(1, len(A)):
        key = A[j]
        i = j - 1
        while i >= 0 and A[i] > key:
            A[i + 1] = A[i]
            i = i - 1
        A[i + 1] = key
    return A

# %%
# Code from L03

def merge(A, p, q, r):    
    n1 = q - p + 1
    n2 = r - q
    
    L = [0] * n1
    R = [0] * n2

    for i in list(range(n1)):
        L[i] = A[p + i - 1]
    
    for j in list(range(n2)):
        R[j] = A[q + j]
    L.append(float('inf'))
    R.append(float('inf'))

    i = 1 - 1     # Subtract 1 to adjust to Python indexing
    j = 1 - 1     # Subtract 1 to adjust to Python indexing
    
    for k in list(range(p - 1, r)):     # Subtract 1 from q to adjust to Python range object
        if L[i] <= R[j]:
            A[k] = L[i]
            i = i + 1
        else:
            A[k] = R[j]
            j = j + 1
    return A

# %%
# See p 34 book for algo
# Note to self, remember correct indexing. 
def merge_sort(A, p, r):
    if p < r:
        q = (p + r) // 2
        merge_sort(A, p, q)
        merge_sort(A, q + 1, r)
        merge(A, p, q, r)
    return A

# %%
def combined_sort(A, p=1, n=10):
    """
    Combined algorithm mergesort switching to insertion sort for small data
    """
    if len(A) < n:
        insertion_sort(A)
    else:
        merge_sort(A, p, len(A))
    return A

# %% [markdown]
# ### Benchmarking

# %%
benchmark_results_combined = pd.DataFrame(columns = 
                                          ['input ordering', 'input size',
                                           'run number','sorting algorithm',
                                           'time'])

# %%
# Source TP 2019

for input_ordering in ['sorted','reversed','random','identical']:
    
    for input_size in range(1,4):
        rng = np.random.default_rng(12)
        test_data = np.random.uniform(size=10**input_size)
        
        if input_ordering == 'sorted':
            test_data = sorted(test_data)
        
        elif input_ordering == 'reversed':
            test_data = list(reversed(sorted(test_data)))
        
        elif input_ordering == 'identical':
            test_data = [test_data]*0
            
        clock = timeit.Timer(stmt='sort_func(copy(data))',
                     globals={'sort_func': combined_sort,
                              'data': test_data,
                              'copy': copy.copy})
        n_ar, t_ar = clock.autorange()
        t = clock.repeat(repeat=5, number=n_ar)  
        
        print(f"Combined sort minimum time on {input_ordering} \
              data of size 10^{input_size}:", min(t)/n_ar)
        
        
        for run_number in range(5):
            benchmark_results_combined = \
                                benchmark_results_combined.append(
                                {'input ordering': input_ordering,                        
                                 'input size':10**input_size,
                                  'run number':run_number+1,
                                  'sorting algorithm':'combined_sort',
                                  'time':t[run_number]/n_ar},
                                     ignore_index=True)
# Out:
# Combined sort minimum time on sorted               data of size 10^1: 4.0502140000171496e-05
# Combined sort minimum time on sorted               data of size 10^2: 0.0005105866000012611
# Combined sort minimum time on sorted               data of size 10^3: 0.007146997999989253
# Combined sort minimum time on reversed               data of size 10^1: 4.343642000021646e-05
# Combined sort minimum time on reversed               data of size 10^2: 0.0005580190000000584
# Combined sort minimum time on reversed               data of size 10^3: 0.007087903999999981
# Combined sort minimum time on random               data of size 10^1: 5.48356800001784e-05
# Combined sort minimum time on random               data of size 10^2: 0.0006896444000012707
# Combined sort minimum time on random               data of size 10^3: 0.009121948000029079
# Combined sort minimum time on identical               data of size 10^1: 9.42202999995061e-07
# Combined sort minimum time on identical               data of size 10^2: 9.361764999994193e-07
# Combined sort minimum time on identical               data of size 10^3: 9.403965000001336e-07

# %%
benchmark_results_combined
# Out:
#    input ordering input size run number sorting algorithm          time
# 0          sorted         10          1     combined_sort  4.083596e-05
# 1          sorted         10          2     combined_sort  4.322782e-05
# 2          sorted         10          3     combined_sort  4.400460e-05
# 3          sorted         10          4     combined_sort  4.050214e-05
# 4          sorted         10          5     combined_sort  5.159240e-05
# 5          sorted        100          1     combined_sort  5.105866e-04
# 6          sorted        100          2     combined_sort  5.332646e-04
# 7          sorted        100          3     combined_sort  5.702426e-04
# 8          sorted        100          4     combined_sort  6.293724e-04
# 9          sorted        100          5     combined_sort  5.884410e-04
# 10         sorted       1000          1     combined_sort  7.289216e-03
# 11         sorted       1000          2     combined_sort  7.146998e-03
# 12         sorted       1000          3     combined_sort  7.334786e-03
# 13         sorted       1000          4     combined_sort  7.470746e-03
# 14         sorted       1000          5     combined_sort  7.352850e-03
# 15       reversed         10          1     combined_sort  4.609682e-05
# 16       reversed         10          2     combined_sort  4.462110e-05
# 17       reversed         10          3     combined_sort  4.413284e-05
# 18       reversed         10          4     combined_sort  4.351752e-05
# 19       reversed         10          5     combined_sort  4.343642e-05
# 20       reversed        100          1     combined_sort  6.249688e-04
# 21       reversed        100          2     combined_sort  5.580190e-04
# 22       reversed        100          3     combined_sort  5.630018e-04
# 23       reversed        100          4     combined_sort  5.680758e-04
# 24       reversed        100          5     combined_sort  5.644926e-04
# 25       reversed       1000          1     combined_sort  7.189406e-03
# 26       reversed       1000          2     combined_sort  7.217896e-03
# 27       reversed       1000          3     combined_sort  7.381276e-03
# 28       reversed       1000          4     combined_sort  7.463810e-03
# 29       reversed       1000          5     combined_sort  7.087904e-03
# 30         random         10          1     combined_sort  6.152924e-05
# 31         random         10          2     combined_sort  5.846322e-05
# 32         random         10          3     combined_sort  5.992998e-05
# 33         random         10          4     combined_sort  5.509146e-05
# 34         random         10          5     combined_sort  5.483568e-05
# 35         random        100          1     combined_sort  7.149942e-04
# 36         random        100          2     combined_sort  6.896444e-04
# 37         random        100          3     combined_sort  7.211370e-04
# 38         random        100          4     combined_sort  7.344168e-04
# 39         random        100          5     combined_sort  7.022712e-04
# 40         random       1000          1     combined_sort  9.519792e-03
# 41         random       1000          2     combined_sort  1.016739e-02
# 42         random       1000          3     combined_sort  9.121948e-03
# 43         random       1000          4     combined_sort  9.268492e-03
# 44         random       1000          5     combined_sort  9.321470e-03
# 45      identical         10          1     combined_sort  9.588965e-07
# 46      identical         10          2     combined_sort  9.484415e-07
# 47      identical         10          3     combined_sort  1.005939e-06
# 48      identical         10          4     combined_sort  9.422030e-07
# 49      identical         10          5     combined_sort  1.057278e-06
# 50      identical        100          1     combined_sort  1.021430e-06
# 51      identical        100          2     combined_sort  9.803925e-07
# 52      identical        100          3     combined_sort  9.832175e-07
# 53      identical        100          4     combined_sort  9.646580e-07
# 54      identical        100          5     combined_sort  9.361765e-07
# 55      identical       1000          1     combined_sort  9.922655e-07
# 56      identical       1000          2     combined_sort  9.481155e-07
# 57      identical       1000          3     combined_sort  9.403965e-07
# 58      identical       1000          4     combined_sort  1.018823e-06
# 59      identical       1000          5     combined_sort  9.922605e-07

# %%
benchmark_results_combined.to_pickle("./benchmark_results_combined.pkl")

# %%
pd.read_pickle("./benchmark_results_combined.pkl")
# Out:
#    input ordering input size run number sorting algorithm          time
# 0          sorted         10          1     combined_sort  4.083596e-05
# 1          sorted         10          2     combined_sort  4.322782e-05
# 2          sorted         10          3     combined_sort  4.400460e-05
# 3          sorted         10          4     combined_sort  4.050214e-05
# 4          sorted         10          5     combined_sort  5.159240e-05
# 5          sorted        100          1     combined_sort  5.105866e-04
# 6          sorted        100          2     combined_sort  5.332646e-04
# 7          sorted        100          3     combined_sort  5.702426e-04
# 8          sorted        100          4     combined_sort  6.293724e-04
# 9          sorted        100          5     combined_sort  5.884410e-04
# 10         sorted       1000          1     combined_sort  7.289216e-03
# 11         sorted       1000          2     combined_sort  7.146998e-03
# 12         sorted       1000          3     combined_sort  7.334786e-03
# 13         sorted       1000          4     combined_sort  7.470746e-03
# 14         sorted       1000          5     combined_sort  7.352850e-03
# 15       reversed         10          1     combined_sort  4.609682e-05
# 16       reversed         10          2     combined_sort  4.462110e-05
# 17       reversed         10          3     combined_sort  4.413284e-05
# 18       reversed         10          4     combined_sort  4.351752e-05
# 19       reversed         10          5     combined_sort  4.343642e-05
# 20       reversed        100          1     combined_sort  6.249688e-04
# 21       reversed        100          2     combined_sort  5.580190e-04
# 22       reversed        100          3     combined_sort  5.630018e-04
# 23       reversed        100          4     combined_sort  5.680758e-04
# 24       reversed        100          5     combined_sort  5.644926e-04
# 25       reversed       1000          1     combined_sort  7.189406e-03
# 26       reversed       1000          2     combined_sort  7.217896e-03
# 27       reversed       1000          3     combined_sort  7.381276e-03
# 28       reversed       1000          4     combined_sort  7.463810e-03
# 29       reversed       1000          5     combined_sort  7.087904e-03
# 30         random         10          1     combined_sort  6.152924e-05
# 31         random         10          2     combined_sort  5.846322e-05
# 32         random         10          3     combined_sort  5.992998e-05
# 33         random         10          4     combined_sort  5.509146e-05
# 34         random         10          5     combined_sort  5.483568e-05
# 35         random        100          1     combined_sort  7.149942e-04
# 36         random        100          2     combined_sort  6.896444e-04
# 37         random        100          3     combined_sort  7.211370e-04
# 38         random        100          4     combined_sort  7.344168e-04
# 39         random        100          5     combined_sort  7.022712e-04
# 40         random       1000          1     combined_sort  9.519792e-03
# 41         random       1000          2     combined_sort  1.016739e-02
# 42         random       1000          3     combined_sort  9.121948e-03
# 43         random       1000          4     combined_sort  9.268492e-03
# 44         random       1000          5     combined_sort  9.321470e-03
# 45      identical         10          1     combined_sort  9.588965e-07
# 46      identical         10          2     combined_sort  9.484415e-07
# 47      identical         10          3     combined_sort  1.005939e-06
# 48      identical         10          4     combined_sort  9.422030e-07
# 49      identical         10          5     combined_sort  1.057278e-06
# 50      identical        100          1     combined_sort  1.021430e-06
# 51      identical        100          2     combined_sort  9.803925e-07
# 52      identical        100          3     combined_sort  9.832175e-07
# 53      identical        100          4     combined_sort  9.646580e-07
# 54      identical        100          5     combined_sort  9.361765e-07
# 55      identical       1000          1     combined_sort  9.922655e-07
# 56      identical       1000          2     combined_sort  9.481155e-07
# 57      identical       1000          3     combined_sort  9.403965e-07
# 58      identical       1000          4     combined_sort  1.018823e-06
# 59      identical       1000          5     combined_sort  9.922605e-07
